// %% [markdown]
// `@NivasDonthireddy - Github Pages`

// %% [markdown]
// `String Assignments`

// %% [markdown]
// `A-01`

// %%
class Tester{    
    public static String moveSpecialCharacters(String str){
        int ch_ascii;
        String str1="",str2="";
        for (int i=0;i<str.length();i++){
            ch_ascii=(int)(str.charAt(i));
            if ( (ch_ascii>=65 && ch_ascii<=90) || (ch_ascii>=97 && ch_ascii<=122) ){
                str1 = str1+str.charAt(i);
            } 
            else{
                str2 = str2+str.charAt(i);
            }
        }
        str = str1+str2;
        return str;
    }
}

// inside main
String str = "He@#$llo!*&";
Tester obj1 = new Tester();
System.out.println(obj1.moveSpecialCharacters(str));
// Out:
// Hello@#$!*&

// %% [markdown]
// `A-02`

// %%
class Tester{
    public static boolean checkPalindrome(String str){
        String str_rev = "";
        for(int i=str.length()-1;i>=0;i--){
            str_rev=str_rev+str.charAt(i);
        }
        if (str.equals(str_rev)){
            return true;
        }
        else{
            return false;
        }
    }
}
    
String str = "radar";
// String str_rev="";
Tester obj1 = new Tester();
if(obj1.checkPalindrome(str)){
    System.out.println("The string is a palindrome!");
}
else{
    System.out.println("The string is not a palindrome!");
}
// Out:
// The string is a palindrome!

// %% [markdown]
// `A-03`

// %%
class Tester {
    public static String reverseEachWord(String str){
        str = str+" ";
        int ch_ascii;
        String str1="";
        String str_final="";
        String str1_rev="";
        for (int i=0;i<str.length();i++){
            ch_ascii=(char)(str.charAt(i));
            if(ch_ascii!=32){
                str1 = str1+str.charAt(i);
            }
            else{
                for(int j=str1.length()-1;j>=0;j--){
                    str1_rev = str1_rev+str1.charAt(j);
                }
                str_final=str_final+str1_rev+" ";
                str1_rev="";
                str1="";
            }
        }
        str_final = str_final.substring(0,str.length()-1);
        return str_final;
    }
}

String str = "all cows eat grass";
Tester obj1 = new Tester();
System.out.println(obj1.reverseEachWord(str));
// Out:
// lla swoc tae ssarg

// %% [markdown]
// `A-04`

// %%
class Tester {
    public static int findHighestOccurrence(String str){
        int char_int[]=new int[str.length()];
        int count_int[] = new int[str.length()];
        int ch_ascii;
        int count=0;
        for(int i=0;i<str.length();i++){
            ch_ascii=(char)(str.charAt(i));
            char_int[i]=ch_ascii;
        }
        for (int i=0;i<str.length();i++){
            for (int j:char_int){
                if(char_int[i]==j){
                    count=count+1;
                }
            }
            count_int[i]=count;
            count=0;
        }
        Arrays.sort(count_int);
        int val = count_int[count_int.length-1];
        return val;
    }
}

//inside main
String str = "success";
Tester obj1 = new Tester();
System.out.println(obj1.findHighestOccurrence(str));
// Out:
// 3

// %% [markdown]
// `A-05`

// %%
// Not solved Completely yet.......
class Tester{    
    
    public static String removeDuplicatesandSpaces(String str){
        String str1="";
        int count=0;
        for(int i=0;i<str.length();i++){
            for(int j=0;j<str.length();j++){
                if(str.charAt(i)==str.charAt(j)){
                    count_int[i] = count+1;
                }
            }
            count=0;
            
        }
        System.out.println(str1);
        return null;
    }
}

// String str = "object oriented programming";
String str = "hello";
Tester obj1 = new Tester();
System.out.println(obj1.removeDuplicatesandSpaces(str));
// Out:
// hello
// null

// %% [markdown]
// <hr>

// %% [markdown]
// `Arrays - Assignments`

// %% [markdown]
// `A-01`

// %%
class Teacher{
    String teacherName;
    String subject;
    double salary;
    
    public Teacher(String teacherName,String subject,double salary){
        this.teacherName=teacherName;
        this.subject = subject;
        this.salary = salary;
    }
    
    public String getTeacherName(){
        return this.teacherName;
    }
    
    public void setTeacherName(String teacherName){
        this.teacherName=teacherName;
    }
    
    public void setSubject(String subject){
        this.subject=subject;
    }
    
    public String getSubject(){
        return this.subject;
    }
    
    public void setSalary(double salary){
        this.salary=salary;
    }
    
    public double getSalary(){
        return this.salary;
    }
}

// inside main class
Teacher t1 = new Teacher("Alex","Java Fundamentals",1200L);
Teacher t2 = new Teacher("John","RDBMS",800L);
Teacher t3 = new Teacher("Sam","Networking",500L);
Teacher t4 = new Teacher("Maria","Python",900L);

Teacher t_arr[] = {t1,t2,t3,t4};

for (Teacher i:t_arr){
    System.out.print("Name : "+i.getTeacherName()+", "+"Subject : "+i.getSubject()+", "+"Salary : "+i.getSalary());
    System.out.println();
}
// Out:
// Name : Alex, Subject : Java Fundamentals, Salary : 1200.0
// Name : John, Subject : RDBMS, Salary : 800.0
// Name : Sam, Subject : Networking, Salary : 500.0
// Name : Maria, Subject : Python, Salary : 900.0

// %% [markdown]
// `A-02`

// %%
class Tester {
    
    public static double[] findDetails(double[] salary) {
        double count_less_avg=0;
        double count_more_avg=0;
        double sum=0,average;
        double final_arr[]=new double[3];
        for(int i=0;i<salary.length;i++){
            sum = sum+salary[i];
        }
        average = sum/salary.length;
        for (double i:salary){
            if(i>average){
                count_less_avg++;
            }
            else if(i<average){
                count_more_avg++;
            }
        }
        final_arr[0]=average;
        final_arr[1]=count_less_avg;
        final_arr[2]=count_more_avg;
        return final_arr;     
    }
}       

Tester obj1=new Tester();
double[] salary = { 23500.0, 25080.0, 28760.0, 22340.0, 19890.0 };
double[] details = obj1.findDetails(salary);

System.out.println("Average salary: "+ details[0]);
System.out.println("Number of salaries greater than the average salary: "+ details[1]);
System.out.println("Number of salaries lesser than the average salary: "+ details[2]);
// Out:
// Average salary: 23914.0
// Number of salaries greater than the average salary: 2.0
// Number of salaries lesser than the average salary: 3.0

// %% [markdown]
// `A-03`

// %%
class Tester {
    
   public static int[] findLeapYears(int year){
       int years_arr[] = new int[15];
       if(year%400==0 || (year%4==0 && year%100!=0)){
           years_arr[0]=year;
       }
       else{
           for(int i=year+1;i<=year+4;i++){
               if(i%400==0 || (i%4==0 && i%100!=0)){
                   years_arr[0]=i;
                   break;
               }
           }
       }
       int sum = years_arr[0];
       for(int i=1;i<years_arr.length;i++){
           sum = sum + 4;
           years_arr[i]=sum;
       }
       return years_arr;
   }
}    

int year = 2000;
int[] leapYears;
Tester obj1 = new Tester();
leapYears=obj1.findLeapYears(year);
for ( int index = 0; index<leapYears.length; index++ ) {
   System.out.print(leapYears[index]+" ");
}
// Out:
// 2000 2004 2008 2012 2016 2020 2024 2028 2032 2036 2040 2044 2048 2052 2056

// %% [markdown]
// `A-04`

// %%
class Student{
    int[] marks;
    char[] grade;
    public Student(int[] marks){
        this.marks = marks;
        this.grade = new char[7];
    }
    
    public void findGrade(){
        for(int i=0;i<marks.length;i++){
            if(this.marks[i]>=92){
                grade[i]='E';
            }
            else if(this.marks[i]>=85 && this.marks[i]<92){
                grade[i]='A';
            }
            else if(this.marks[i]>=70 && this.marks[i]<85){
                grade[i]='B';
            }
            else if(this.marks[i]>=65 && this.marks[i]<70){
                grade[i]='C';
            }
            else if(this.marks[i]<65){
                grade[i]='D';
            }
        }
    }
    
    public int[] getMarks(){
        return this.marks;
    }
    
    public void setMarks(int[] marks){
        this.marks = marks;
    }
    
    public char[] getGrade(){
        return this.grade;
    }
    
    public void setGrade(char[] grade){
        this.grade=grade;
    }
}

int[] marks = { 79, 87, 97, 65, 78, 99, 66 }; 
Student student = new Student(marks);
student.findGrade();
System.out.println("Grades corresponding to the marks are : ");
char[] grades = student.getGrade();
for (int index = 0; index < grades.length; index++) {
    System.out.print(grades[index] + " ");

}
// Out:
// Grades corresponding to the marks are :
// B A E C B E C

// %% [markdown]
// `A-05`

// %%
class Tester {
public static int[] findNumbers(int num1, int num2) {
    int[] numbers = new int[6];
    int sum;
    int r=0;
    int temp;
    int count=0;
    if(num1<num2){
        for(int i=num1;i<=num2;i++){
            sum=0;
            temp=i;
            while(temp!=0){
                r=temp%10;
                temp = temp/10;
                sum = sum +r;
            }
                if(sum%3==0 && i%5==0){
                    numbers[count]=i;
                    count=count+1;
                }
        }
    }
    return numbers;
}
}

//inside main
int num1 = 10;
int num2 = 30;

Tester obj1 = new Tester();
int[] numbers = obj1.findNumbers(num1, num2);
if (numbers[0] == 0) {
    System.out.println("There is no such number!");
}
else {
    for (int index = 0; index <= numbers.length - 1; index++) {
        if (numbers[index] == 0) {
            break;
        }
        System.out.println(numbers[index]);
    }
}
// Out:
// 15
// 30

// %% [markdown]
// `A-06`

// %% [markdown]
// <hr>`

// %% [markdown]
// `Encapsulation - Assignment 2`

// %%
class MovieTicket {
    private int movieId;
    private int noOfSeats;
    private double costPerTicket;
    
    MovieTicket(int movieId,int noOfSeats){
        this.movieId=movieId;
        this.noOfSeats=noOfSeats;
        this.setCostPerTicket();
    }
    
    public int getMovieId(){
        return this.movieId;
    }
    
    public void setMovieId(int movieId){
        this.movieId=movieId;
    }
    
    public void setNoOfSeats(int noOfSeats){
        this.noOfSeats=noOfSeats;
    }
    
    public int getNoOfSeats(){
        return this.noOfSeats;
    }
    
    public void setCostPerTicket(){
        
        if(this.movieId==111){
            this.costPerTicket=7;
        }
        else if(this.movieId==112){
            this.costPerTicket=8;
        }
        else if(this.movieId==113){
            this.costPerTicket = 8.5;
        }
        else{
            this.costPerTicket = 0;
        }
    }
    
    public double getCostPerTicket(){
        return this.costPerTicket;
    }
    
    public double calculateTotalAmount(){
        return ((this.costPerTicket*this.noOfSeats)*1.02);
        }
}


MovieTicket movieTicket = new MovieTicket(112, 3);
double amount = movieTicket.calculateTotalAmount();
if (amount==0)
    System.out.println("Sorry! Please enter valid movie Id and number of seats");
else
    System.out.println("Total amount for booking : $" + Math.round(amount*100)/100.0);
// Out:
// Total amount for booking : $24.48

// %% [markdown]
// <hr>

// %% [markdown]
// `Strings`

// %% [markdown]
// Need to know what is the difference between these two<br>
// ![image.png](attachment:c38894c6-a21a-4b00-9e5e-8234bf692184.png)

// %%
class Tester{
    public static String removeWhiteSpaces(String str){
        String str1 = "";
        for (int i=0;i<str.length();i++){
            if(str.charAt(i)!=' '){
                str1 = str1+str.charAt(i);
            }
        }
        return str1;
    }
}

String str = "Hello   How are you   ";
Tester obj = new Tester();
str = obj.removeWhiteSpaces(str);
System.out.println(str);
// Out:
// HelloHowareyou

// %% [markdown]
// `Array - quiz `  -- Questions 7 & 8 are pending to attempt

// %% [markdown]
// <hr>

// %% [markdown]
// `Static`

// %%
class Bill{
    private static int counter;
    private String billId;
    private String paymentMode;
    
    static{
        counter=9000;
    }
    
    public Bill(String paymentMode){
        this.paymentMode = paymentMode;
        this.billId = "B"+ ++counter;
    }
    
    public String getBillId(){
        return this.billId;
    }
    
    public void setBillId(String billId){
        this.billId = billId;
    }
    
    public String getPaymentMode(){
        return this.paymentMode;
    }
    
    public void setPaymentMode(String paymentMode){
        this.paymentMode = paymentMode;
    }
    
    public static int getCounter(){
        return counter;
    }
    
    
    
}

Bill bill1 = new Bill("DebitCard");
Bill bill2 = new Bill("PayPal");

//Create more objects and add them to the bills array for testing your code

Bill[] bills = { bill1, bill2};

for (Bill bill : bills) {
    System.out.println("Bill Details");
    System.out.println("Bill Id: " + bill.getBillId());
    System.out.println("Payment method: " + bill.getPaymentMode());
    System.out.println();
}
// Out:
// Bill Details
// Bill Id: B9001
// Payment method: DebitCard
//
// Bill Details
// Bill Id: B9002
// Payment method: PayPal

// %% [markdown]
// `Exception Handling - Exercise`

// %%
// Implement user defined exception classes 
class InvalidJobProfileException extends Exception{
    public InvalidJobProfileException(String msg) {
        super(msg);
    }
}

class InvalidNameException extends Exception{
    public InvalidNameException(String msg) {
        super(msg);
    }
}

class InvalidAgeException extends Exception{
    public InvalidAgeException(String msg) {
        super(msg);
    }
}


class Applicant {

    private String name;
    private String jobProfile;
    private int age;

    public String getName() {
        return name;
    }
      
    public void setName(String name) {
        this.name = name;
    }
      
    public String getJobProfile() {
         return jobProfile;
    }
      
    public void setJobProfile(String jobProfile) {
        this.jobProfile = jobProfile;
    }
      
    public int getAge() {
        return age;
    }
      
    public void setAge(int age) {
        this.age = age;
    }
}


class Validator{
    String jobProfiles[] = {"Associate","Clerk","Executive","Officer"};

    public boolean validateName(String name) {
        if(name==null || name=="") {
            return false;
        }
        else {
            return true;
        }
    }

    public boolean validateJobProfile(String jobProfile) {
        for (String i:jobProfiles) {
            if(i.equalsIgnoreCase(jobProfile)) {
                return true;
            }
        }
        return false;
        }

    public boolean validateAge(int age) {
        if(age>=18 && age<=30) {
            return true;
        }
        else {
            return false;
        }
    }

    public void validate(Applicant applicant) throws InvalidNameException,InvalidJobProfileException,InvalidAgeException{
            if(!validateName(applicant.getName())) {
                throw new InvalidNameException("Invalid name");
            }
        if(!validateAge(applicant.getAge())) {
            throw new InvalidAgeException("Invalid age");
        }

        if(!validateJobProfile(applicant.getJobProfile())) {
            throw new InvalidJobProfileException("Invalid job post");
        }
    }

}

// inside main method
try {
    Applicant applicant= new Applicant();
    applicant.setName("Jenny");
    applicant.setJobProfile("Clerk");
    applicant.setAge(23);

    Validator validator = new Validator();

    validator.validate(applicant);
    System.out.println("Application submitted successfully!");
}
catch (InvalidNameException|InvalidJobProfileException|InvalidAgeException e) {
    System.out.println(e.getMessage());
}
// Out:
// Application submitted successfully!

// %% [markdown]
// `Association Exercise`

// %%
class Driver {

    private String driverName;
    private float averageRating;

    public Driver(String driverName, float averageRating){
        this.driverName=driverName;
        this.averageRating=averageRating;
    }

    public String getDriverName(){
        return this.driverName;
    }

    public void setDriverName(String driverName){
        this.driverName=driverName;
    }

    public float getAverageRating(){
        return this.averageRating;
    }

    public void setAverageRating(float averageRating){
        this.averageRating=averageRating;
    }

    //DO NOT MODIFY THE METHOD
    //Your exercise might not be verified if the below method is modified
    public String toString(){
        return "Driver\ndriverName: "+this.driverName+"\naverageRating: "+this.averageRating;
    }
}


class CabServiceProvider{
    //Implement your code here
    private String cabServiceName;
    private int totalCabs;

    public CabServiceProvider(String cabServiceName,int totalCabs) {
        this.cabServiceName = cabServiceName;
        this.totalCabs = totalCabs;
    }

    public double calculateRewardPrice(Driver driver) {
        double bonus=0;
        if(this.cabServiceName.equals("Halo")) {
            if((driver.getAverageRating() <= 5) && (driver.getAverageRating() >=4.5)) {
                bonus = 10*driver.getAverageRating();
            }
            else if((driver.getAverageRating() < 4.5) && (driver.getAverageRating() >=4)) {
                bonus = 5*driver.getAverageRating();
            }
        }
        else if(this.cabServiceName.equals("Aber")) {
            if((driver.getAverageRating() <= 5) && (driver.getAverageRating() >=4.5)) {
                bonus = 8*driver.getAverageRating();
            }
            else if((driver.getAverageRating() < 4.5) && (driver.getAverageRating() >=4)) {
                bonus = 3*driver.getAverageRating();
            }
        }
        return bonus;
    }

    public String getCabServiceName() {
        return cabServiceName;
    }

    public void setCabServiceName(String cabServiceName) {
        this.cabServiceName = cabServiceName;
    }

    public int getTotalCabs() {
        return totalCabs;
    }

    public void setTotalCabs(int totalCabs) {
        this.totalCabs = totalCabs;
    }


}

CabServiceProvider cabServiceProvider1 = new CabServiceProvider("Halo", 50);

Driver driver1 = new Driver("Luke", 4.8f);
Driver driver2 = new Driver("Mark", 4.2f);
Driver driver3 = new Driver("David", 3.9f);

Driver[] driversList = { driver1, driver2, driver3 };
for (Driver driver : driversList) {
    System.out.println("Driver Name: "+driver.getDriverName());
    double bonus = cabServiceProvider1.calculateRewardPrice(driver);
    if (bonus>0)
        System.out.println("Bonus: $"+bonus+"\n");
    else
        System.out.println("Sorry, bonus is not available!");
}
// Out:
// Driver Name: Luke
// Bonus: $48.0
//
// Driver Name: Mark
// Bonus: $21.0
//
// Driver Name: David
// Sorry, bonus is not available!

// %% [markdown]
// `Static - A-02`

// %%
class Participant {
    //Implement your code here
    private static int counter;
    static {
        counter=10000;
    }

    private String registrationId;
    private String name;
    private long contactNumber;
    private String city;

    public Participant(String name,long contactNumber,String city) {
        this.city = city;
        this.contactNumber = contactNumber;
        this.name = name;
        counter++;
        this.setRegistrationId("D"+counter);
    }



    public static int getCounter() {
        return counter;
    }

    public static void setCounter(int counter) {
        Participant.counter = counter;
    }

    public String getRegistrationId() {
        return registrationId;
    }

    public void setRegistrationId(String registrationId) {
        this.registrationId = registrationId;
    }

    public String getName() {
        return name;
    }

    public void setName(String name) {
        this.name = name;
    }

    public long getContactNumber() {
        return contactNumber;
    }

    public void setContactNumber(long contactNumber) {
        this.contactNumber = contactNumber;
    }

    public String getCity() {
        return city;
    }

    public void setCity(String city) {
        this.city = city;
    }

}

Participant participant1 = new Participant("Franklin", 7656784323L, "Texas");
Participant participant2 = new Participant("Merina", 7890423112L, "New York");

//Create more objects and add them to the participants array for testing your code

Participant[] participants = { participant1, participant2 };

for (Participant participant : participants) {
    System.out.println("Hi "+participant.getName()+"! Your registration id is "+participant.getRegistrationId());
}
// Out:
// Hi Franklin! Your registration id is D10006
// Hi Merina! Your registration id is D10007

// %% [markdown]
// `Static A-03`

// %%
class Booking{
    //Implement your code here
    private String customerEmail;
    private int seatsRequired;
    private boolean isBooked;
    private static int seatsAvailable;

    static {
        seatsAvailable = 400;
    }

    public Booking(String customerEmail, int seatsRequired) {
        this.customerEmail = customerEmail;
        this.seatsRequired = seatsRequired;
        if(seatsAvailable<seatsRequired) {
            this.setBooked(false);
        }
        else {
            this.setBooked(true);
            seatsAvailable = seatsAvailable - seatsRequired;
        }
    }

    public String getCustomerEmail() {
        return customerEmail;
    }

    public void setCustomerEmail(String customerEmail) {
        customerEmail = customerEmail;
    }

    public int getSeatsRequired() {
        return seatsRequired;
    }

    public void setSeatsRequired(int seatsRequired) {
        this.seatsRequired = seatsRequired;
    }

    public boolean isBooked() {
        return isBooked;
    }

    public void setBooked(boolean isBooked) {
        this.isBooked = isBooked;
    }

    public static int getSeatsAvailable() {
        return seatsAvailable;
    }

    public static void setSeatsAvailable(int seatsAvailable) {
        Booking.seatsAvailable = seatsAvailable;
    }


}

// inside main
Booking booking1 = new Booking("jack@email.com", 100);
Booking booking2 = new Booking("jill@email.com", 350);

//Create more objects and add them to the bookings array for testing your code

Booking[] bookings = { booking1, booking2 };

for (Booking booking : bookings) {
    if (booking.isBooked()) {
        System.out.println(booking.getSeatsRequired()+" seats successfully booked for "+booking.getCustomerEmail());
    }
    else {
        System.out.println("Sorry "+booking.getCustomerEmail()+", required number of seats are not available!");
        System.out.println("Seats available: "+Booking.getSeatsAvailable());
    }
 }
// Out:
// 100 seats successfully booked for jack@email.com
// Sorry jill@email.com, required number of seats are not available!
// Seats available: 200

// %% [markdown]
// `Aggregation - A-02`

// %%
class Author {
    //Implement your code here
    private String name;
    private String emailId;
    private char gender;

    public Author(String name,String emailId,char gender) {
        this.emailId = emailId;
        this.name = name;
        this.gender = gender;
    }

    public String getName() {
        return name;
    }

    public void setName(String name) {
        this.name = name;
    }

    public String getEmailId() {
        return emailId;
    }

    public void setEmailId(String emailId) {
        this.emailId = emailId;
    }

    public char getGender() {
        return gender;
    }

    public void setGender(char gender) {
        this.gender = gender;
    }


}


class Book {
    //Implement your code here 
    private String name;
    private Author author;
    private double price;
    private int quantity;

    public Book(String name,Author author,double price,int quantity) {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.author = author;
    }

    public void displayAuthorDetails() {
        System.out.println("Dispalying author details");
        System.out.println("Author name: "+author.getName());
        System.out.println("Author email: "+author.getEmailId());
        System.out.println("Author gender: "+author.getGender());
    }

    public String getName() {
        return name;
    }

    public void setName(String name) {
        this.name = name;
    }

    public Author getAuthor() {
        return author;
    }

    public void setAuthor(Author author) {
        this.author = author;
    }

    public double getPrice() {
        return price;
    }

    public void setPrice(double price) {
        this.price = price;
    }

    public int getQuantity() {
        return quantity;
    }

    public void setQuantity(int quantity) {
        this.quantity = quantity;
    }


}

Author author = new Author("Nivas","dlnivas@hotmail.com",'M');
Book book = new Book("Effective Java",author,45,15);
book.displayAuthorDetails();
// Out:
// Dispalying author details
// Author name: Nivas
// Author email: dlnivas@hotmail.com
// Author gender: M

// %%
class Room {
    //Implement your code here 
    private int roomNo;
    private int capacity;
    private static int roomCounter;
    
    static {
        roomCounter = 500;
    }

    public Room() {
        roomCounter++;
        this.roomNo = roomCounter;
        this.capacity = 4;
    }

    public int getRoomNo() {
        return roomNo;
    }

    public void setRoomNo(int roomNo) {
        this.roomNo = roomNo;
    }

    public int getCapacity() {
        return capacity;
    }

    public void setCapacity(int capacity) {
        this.capacity = capacity;
    }

    public static int getRoomCounter() {
        return roomCounter;
    }

    public static void setRoomCounter(int roomCounter) {
        Room.roomCounter = roomCounter;
    }


    //Uncomment the below method after implementation before verifying 
    //DO NOT MODIFY THE METHOD
    /*
    public String toString(){
        return "Room\nroomNo: "+this.roomNo+"\ncapacity: "+this.capacity;
    }
    */ 
}

class Member {
    //Implement your code here 
    private int memberId;
    private String name;
    private Room room;

    public Member(int memberId,String name) {
        this.name = name;
        this.memberId = memberId;
    }

    public int getMemberId() {
        return memberId;
    }

    public void setMemberId(int memberId) {
        this.memberId = memberId;
    }

    public String getName() {
        return name;
    }

    public void setName(String name) {
        this.name = name;
    }

    public Room getRoom() {
        return room;
    }

    public void setRoom(Room room) {
        this.room = room;
    }

    //Uncomment the below method after implementation before verifying 
    //DO NOT MODIFY THE METHOD
    /*
    public String toString(){
        return "Member\nmemberId: "+this.memberId+"\nname: "+this.name;
    }
    */
}

class Admin {
    //Implement your code here
    public void assignRoom(Room[] rooms,Member member) {		
        for(Room room:rooms) {
            while(room.getCapacity()>0) {
                member.setRoom(room);
                room.setCapacity(room.getCapacity()-1);
            }
        }
    }
}

Room room1 = new Room();
Room room2 = new Room();
Room room3 = new Room();
Room room4 = new Room();
Room room5 = new Room();

Room[] totalRooms = { room1, room2, room3, room4, room5 };

Admin admin = new Admin();

Member member1 = new Member(101, "Serena");
Member member2 = new Member(102, "Martha");
Member member3 = new Member(103, "Nia");
Member member4 = new Member(104, "Maria");
Member member5 = new Member(105, "Eva");

Member[] members = { member1, member2, member3, member4, member5 };

for (Member member : members) {
    admin.assignRoom(totalRooms, member);
    if(member.getRoom()!=null) {
        System.out.println("Hi "+member.getName()+"! Your room number is "+member.getRoom().getRoomNo());
    }
    else {
        System.out.println("Hi "+member.getName()+"! No room available");
    }
}
// Out:
// Hi Serena! Your room number is 504
// Hi Martha! No room available
// Hi Nia! No room available
// Hi Maria! No room available
// Hi Eva! No room available

// %%
room5.getRoomNo()
// Out:
// 504
