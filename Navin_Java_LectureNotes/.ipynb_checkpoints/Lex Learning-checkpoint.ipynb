// %% [markdown]
// `@nivasdonthireddy GITHUB PAGES`
//
// `Notes` - `Lex Learnings`

// %% [markdown]
// `Flow chart Symbols`
//
// ![image.png](attachment:32dbac73-5911-4ec8-bd12-51b89db7f0c1.png)

// %% [markdown]
// `Keywords in Java`
//
// ![image.png](attachment:df0ecf74-1ced-4061-8e70-26ca35679695.png)

// %% [markdown]
// `Rules to name the variables`
//
// ![image.png](attachment:62a5744d-97f2-4e0d-bcb1-821eb46fcb7a.png)

// %% [markdown]
// `Data Types in Java`
//
// ![image.png](attachment:72ea86ee-f6c8-421b-be72-60c72fdf3db7.png)

// %% [markdown]
// `Primitive Data Types in Java`
//
// ![image.png](attachment:5986ffb9-8c8d-46ed-b0dd-574c1b8a1782.png)
// ![image.png](attachment:69cdeff7-9d5c-43ce-9480-a898959e06b7.png)

// %% [markdown]
// `Non Primitive Data Types`
//
// ![image.png](attachment:a44bf45a-ba01-47b3-8e80-0d35b0458eb5.png)

// %% [markdown]
// #### `Operators in Java`

// %% [markdown]
// `unary operators in Java`
//
// ![image.png](attachment:ff9f94f8-8427-4581-b96e-96dade7a7514.png)

// %% [markdown]
// `Arithmetic Operators`
//
// ![image.png](attachment:cfdec58a-f375-4057-a5e9-7997ade00d5d.png)

// %% [markdown]
// `Relational Operators`
//
// ![image.png](attachment:491f9623-cf89-4722-8cdc-bbe329838995.png)

// %% [markdown]
// `Logical Operators`
//
// ![image.png](attachment:bc0627a2-73c1-4fd4-9ac8-02e93fcb83c7.png)

// %% [markdown]
// `Ternary Operator`
//
// `<condition> ? <value if condition is true> : < value if condition is false> `

// %% [markdown]
// `Assignment Operators`
//
// ![image.png](attachment:4d19189b-d80d-43ed-9531-94f4efa8d51a.png)

// %% [markdown]
// `Operator Precedence in Java (Highest to Lowest)`
//
// ![image.png](attachment:8ff8b7d9-d5c2-400c-a8ee-f7a4ce1e0b6b.png)

// %% [markdown]
// `Tryout`
//
// ![image.png](attachment:8af47373-7731-4565-b285-38eed58194cd.png)

// %% [markdown]
// `Decimal to Binary Conversion`
//
// ![image.png](attachment:9c69b455-65a0-4b72-b0af-cc70b6e67bf7.png)

// %% [markdown]
// `Implicit DataType Conversions in Java`
//
// ![image.png](attachment:058d6d12-051e-47f5-8c22-83aacd46aac1.png)

// %% [markdown]
// `Iteration Control Structures`
//
// ![image.png](attachment:a2058359-023d-4e0c-b0c2-2c79fd64f6a4.png)

// %% [markdown]
// `Break`
//
// In case of while and do-while loops, continue statement skips the remaining code of the loop and passes the control to check the loop condition. Whereas in case of for loop, the control goes to the increment section and then the condition is checked.
//
// ![image.png](attachment:db8bba7c-f222-4801-a8a1-0aac831cb3c2.png)

// %% [markdown]
// <hr>

// %% [markdown]
// `Data Structures`

// %% [markdown]
// ![image.png](attachment:18c6563c-0ff6-40ca-97d5-76ebd31d8045.png)

// %% [markdown]
// `Rounding of the double to 2 decimal places`

// %%
double bonus = 10.32987342;
Math.round(bonus*100.0)/100.0
// Out:
// 10.33

// %% [markdown]
// ![image.png](attachment:4f7ae21a-c6ee-43fb-84f2-dc2ae05937f7.png)

// %% [markdown]
// ![image.png](attachment:acd6f93c-6965-497e-845e-5efecd264d59.png)

// %% [markdown]
// ![image.png](attachment:e1dbb4ba-657b-4475-8ddc-58ff14cb0316.png)

// %% [markdown]
// ![image.png](attachment:ed03558c-8ffe-4237-8b45-b79a096d6038.png)

// %% [markdown]
// ![image.png](attachment:bcd07d45-1e81-420e-92c2-1f7411523dee.png)

// %% [markdown]
// ![image.png](attachment:73248d16-0544-4340-b62a-1fd09d958ddd.png)

// %% [markdown]
//         If a final variable is not initialized during declaration, it is known as blank final variable. We can initialize a blank final variable only in the constructor, else there will be a compilation error. So, if you are marking a variable as final, it can be initialized only once either while declaring or in the constructor of the class.

// %%
class Demo {
    final int num; // blank final variable

    public Demo() {
        this.num = 10;
    }

    public void displayNumber() {
        System.out.println(num);
    }
}

Demo demo = new Demo();
// Out:
// |       public Demo() {
// |       }
// variable num might not have been initialized
