// %% [markdown]
// Infosys - Java Programming - Session -01
//
// Part-1 will be taught by Ma

// %% [markdown]
// **What is Programming ?**<br>
// Structured set of instructions which is used solve a problem with the help of a computer

// %% [markdown]
// **Psuedo Codes, Algorithms & FLowcharts** are just the logics and can be implemented in any programming language if we just look for the syntax|

// %% [markdown]
// ### Java

// %% [markdown]
// Logics are applied on the Data . Data Storage is very important.
// 1. How to store the data
// 2. How to perform operations on Data
// 3. How to write the statements

// %% [markdown]
// For reference Lex id 56623
// *Course:: Programming using Java*

// %% [markdown]
// *Types of data*

// %% [markdown]
// ### Lesson 1

// %% [markdown]
// Terms to know in Java<br>
// ![image.png](attachment:4fc383c9-3b18-4b7b-a842-1a9c4b3f69a5.png)

// %% [markdown]
// *Package*<br>
// `package com.marcusbiel.javacourse.lesson1`

// %% [markdown]
// *import*<br>
//
// `import PackageDeclaration`<br>
// `import com.marcusbiel.lesson1.garage`<br>
// `import static org.junit.Assert*`

// %% [markdown]
// *class*<br>
// Programmers decide on the names that are actual objects that are related to business to ease up the understanding of the project.
//
// class Car{
// }
//
// Class id the Blueprint

// %% [markdown]
// *method*<br>
// (a class may consist of one or more methods)<br>
// By convention name of the method should be a word that best describes the purpose of the method.
// Ex:
// `double(2)=4`
// <br>
// Methods can be operable on names , numbers anything<br>
// Methods can internally call another method and the hierarchy follows.
// Readibility of code is very important so keeping methods as short as possible with 20 lines as maximum
//
// `drive(speed){
// }`
// to use as few method parametres as possible with 5 max

// %% [markdown]
// *variable*<br>
// can be of different data types.
//
// Types of variables
//
// - instance variable
// - static variable
// - local variable
// - parameter
// - argument

// %% [markdown]
// *Public*
// access modifier
//
// <pre>public class Car{
//     public void drive(Speed){
//     }
// }</pre>

// %% [markdown]
// *void*<br>
// (every method you have to define a return value even if you dont want to return any value at all) In that case we can use void

// %% [markdown]
// *@Test*
// we indicate that given method will be used as a test

// %% [markdown]
// *CamelCase*<br>
// `camel_hump` in java camel case is used to club the words

// %% [markdown]
// *dot*<br>
// (dot is used to call the method drive on object Car)
// `car.drive()`

// %% [markdown]
// *colon*
// `;` is used to indicate the end of statements in java
// <pre>
// @Test
// public void shouldDrive(){
//     car.drive(100);
// }
// </pre>

// %% [markdown]
// *object oriented language* <br>
// everything in java is focused around objects.
// <pre>
// class Car(age,maxSpeed)
//
// objects
// myOldCar(10 years old, max speed 120)
// myPorsche(1 year old, max speed 320)
// mumsCar(3 years old, max speed 180)
// </pre>

// %% [markdown]
// *constructor*<br>
// This is a specific method when called on a class will create a specific object for us.
//
// new Car(10,120);

// %% [markdown]
// *variable declaration*<br>
// we need to define variable before hand before using it
//
// `Car myPorsche;`<br>
// I created a new variable of type Car with name myPorsche

// %% [markdown]
// *object allocation*<br>
// variable declaration object creation and allocation can be done in one single line<br>
// `Car myPorsche = new Car(1,320)`

// %% [markdown]
// ### Lesson 2

// %%
public class Person {
    
    private Name personName;
    
    public String helloWorld(){
        return "Hello World";
    }   
    public Name name(){
        return personName;
    }
}
// Out:
// |   public class Person {
// |
// |       private Name personName;
// |
// |       public String helloWorld(){
// |           return "Hello World";
// |       }
// |       public Name name(){
// |           return personName;
// |       }
// |   }
// Unresolved dependencies:
//    - class Name

// %%
package com.marcusbiel.javacourse.lesson2;
import com.marcusbiel.javacourse.lesson3.Name;

import org.junit.Test;
import static org.junit.Assert.assertEquals;
public class PersonTest {    
    @Test
    public void shouldReturnHelloWorld(){
        
        Person marcus = new Person();
        assertEquals("Hello World")
    }
}
public class PersonTest {    
    @Test
    public void shouldReturnHelloWorld(){
        
        Person marcus = new Person();
        assertEquals("Hello World");
    }
}
// Out:
// |   package com.marcusbiel.javacourse.lesson2;
// illegal start of expression

// %% [markdown]
// <hr>

// %%
class HelloWorld {
    public static void main(String[] args) {
        System.out.println("Hello, World!"); 
    }
}
